# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
data=pd.read_csv(r'C:\Users\Anjali\Covidcases1.csv')
data
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %%
data.count
# Out:
# <bound method DataFrame.count of     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %%
data.shape
# Out:
# (26, 6)

# %%
data.dtypes
# Out:
# S. No.                                         int64
# Name of State / UT                            object
# Total Confirmed cases (Indian National)        int64
# Total Confirmed cases ( Foreign National )     int64
# Cured                                          int64
# Death                                          int64
# dtype: object

# %%
data=data.drop(['Total Confirmed cases ( Foreign National )'],axis=1)
data
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  Cured  \
# 0        1     Andhra Pradesh                                       12      1
# 1        2       Chhattisgarh                                        6      0
# 2        3              Delhi                                       38      6
# 3        4            Gujarat                                       43      0
# 4        5            Haryana                                       16     11
# 5        6   Himachal Pradesh                                        4      0
# 6        7          Karnataka                                       20      3
# 7        8             Kerala                                      131     11
# 8        9     Madhya Pradesh                                       23      0
# 9       10        Maharashtra                                      144     15
# 10      11             Odisha                                        3      0
# ...

# %%
data=data.rename(columns={"Total Confirmed cases (Indian National)":"TCCIN","Name of State / UT":"Name of state"})
data
# Out:
#     S. No.      Name of state  TCCIN  Cured  Death
# 0        1     Andhra Pradesh     12      1      0
# 1        2       Chhattisgarh      6      0      0
# 2        3              Delhi     38      6      1
# 3        4            Gujarat     43      0      3
# 4        5            Haryana     16     11      0
# 5        6   Himachal Pradesh      4      0      1
# 6        7          Karnataka     20      3      2
# 7        8             Kerala    131     11      0
# 8        9     Madhya Pradesh     23      0      1
# 9       10        Maharashtra    144     15      4
# 10      11             Odisha      3      0      0
# 11      12         Puducherry      1      0      0
# 12      13             Punjab     29      0      1
# 13      14          Rajasthan     41      3      0
# 14      15         Tamil Nadu     32      1      1
# 15      16          Telengana     34      1      0
# 16      17         Chandigarh      7      0      0
# ...

# %%
data=data.drop(['S. No.'],axis=1)
data
# Out:
#         Name of state  TCCIN  Cured  Death
# 0      Andhra Pradesh     12      1      0
# 1        Chhattisgarh      6      0      0
# 2               Delhi     38      6      1
# 3             Gujarat     43      0      3
# 4             Haryana     16     11      0
# 5    Himachal Pradesh      4      0      1
# 6           Karnataka     20      3      2
# 7              Kerala    131     11      0
# 8      Madhya Pradesh     23      0      1
# 9         Maharashtra    144     15      4
# 10             Odisha      3      0      0
# 11         Puducherry      1      0      0
# 12             Punjab     29      0      1
# 13          Rajasthan     41      3      0
# 14         Tamil Nadu     32      1      1
# 15          Telengana     34      1      0
# 16         Chandigarh      7      0      0
# 17  Jammu and Kashmir     18      1      1
# 18             Ladakh     13      0      0
# 19      Uttar Pradesh     42     11      0
# 20        Uttarakhand      4      0      0
# ...

# %%
data.shape
# Out:
# (26, 4)

# %%
duplicated_rows=data[data.duplicated()]
duplicated_rows.shape
# Out:
# (0, 4)

# %%
data=data.drop_duplicates()
data
# Out:
#         Name of state  TCCIN  Cured  Death
# 0      Andhra Pradesh     12      1      0
# 1        Chhattisgarh      6      0      0
# 2               Delhi     38      6      1
# 3             Gujarat     43      0      3
# 4             Haryana     16     11      0
# 5    Himachal Pradesh      4      0      1
# 6           Karnataka     20      3      2
# 7              Kerala    131     11      0
# 8      Madhya Pradesh     23      0      1
# 9         Maharashtra    144     15      4
# 10             Odisha      3      0      0
# 11         Puducherry      1      0      0
# 12             Punjab     29      0      1
# 13          Rajasthan     41      3      0
# 14         Tamil Nadu     32      1      1
# 15          Telengana     34      1      0
# 16         Chandigarh      7      0      0
# 17  Jammu and Kashmir     18      1      1
# 18             Ladakh     13      0      0
# 19      Uttar Pradesh     42     11      0
# 20        Uttarakhand      4      0      0
# ...

# %%
#data = pd.read_csv(r'C:\Users\Anjali\Covidcases1.csv', index_col ="Name of state" ) 
  
# changing index cols with rename() 
#data=data.rename(index = {Andhra Pradesh:"AP",Himachal Pradesh:"HP"}) 
#data

# %%
sns.relplot(data=data,x='Name of state',y='Cured',hue='TCCIN')

# %%
sns.catplot(data=data,x='Name of state',y='Cured')

# %%
sns.pairplot(data)
